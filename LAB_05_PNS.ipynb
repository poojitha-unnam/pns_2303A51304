# %% [markdown]
# <a href="https://colab.research.google.com/github/poojitha-unnam/pns_2303A51304/blob/main/LAB_05_PNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
def load_data(file_path):
 df=pd.read_csv("/content/employee_data_250-5.csv")
 return df

# %%
def plot_histogram(df,column,bins=10):
 plt.figure(figsize=(8,6))
 sns.histplot(df[column],bins=bins,kde=True,color='blue',edgecolor='black')
 plt.title(f'Histogram of {column}')
 plt.xlabel(column)
 plt.ylabel('Frequency')
 plt.show()

# %%
def plot_scatter(df,x_column,y_column):
  plt.figure(figsize=(8,6))
  sns.scatterplot(x=df[x_column],y=df[y_column],color='purple')
  plt.title(f'Scatter Plot of {y_column} by {x_column}')
  plt.xlabel(x_column)
  plt.ylabel(y_column)
  plt.show()

# %%
def plot_bar_chart(df,x_column,y_column):
  plt.figure(figsize=(8,6))
  sns.barplot(x=df[x_column],y=df[y_column],color='green')
  plt.title(f'Bar Chart of {x_column} vs {y_column}')
  plt.xlabel(x_column)
  plt.ylabel(y_column)
  plt.xticks(rotation=45)
  plt.show()

# %%
file_path='/content/employee_data_250-5.csv'
df=load_data(file_path)

# %%
plot_histogram(df,'Age')

# %%
plot_scatter(df,'Age','Salary')

# %%
plot_bar_chart(df,'Department','Salary')
